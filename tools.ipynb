# %%
import subprocess

source_template = "/home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_{:03d}.obj"
output_template = "/home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_{:04d}.obj"

target_mesh = "/home/frozzzen/Documents/Github/layered-mesh-gaussian/data/hotdog/mesh.obj"
target_mesh = "/home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj"

#scale = "0.0015"

for i in range(1, 11):  # 0001 to 0010
    source = source_template.format(i-1)
    output = output_template.format(i)
    print(f"Processing frame {i}...")
    print(f"Source: {source}")
    print(f"Output: {output}")
    cmd = [
        "python", "align_mesh.py",
        "--source", source,
        "--target", target_mesh,
        "--output", output,
        "--auto_scale",
        #"--scale", scale,
        "--anchor", "center",
        "--bbox_type", "aabb"
    ]

    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)

print("All frames processed.")
# Out:
# Processing frame 1...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_000.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0001.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_000.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0001.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.378088
# Final scale applied: 1.378088
# Translation applied: [-0.00783473 -0.00453725  0.02517921]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0001.obj
# Processing frame 2...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_001.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0002.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_001.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0002.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.349752
# Final scale applied: 1.349752
# Translation applied: [-0.00787924 -0.00512725  0.0251587 ]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0002.obj
# Processing frame 3...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_002.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0003.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_002.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0003.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.329120
# Final scale applied: 1.329120
# Translation applied: [-0.00782174 -0.00517321  0.0251067 ]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0003.obj
# Processing frame 4...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_003.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0004.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_003.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0004.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.318645
# Final scale applied: 1.318645
# Translation applied: [-0.00783874 -0.00512072  0.02425772]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0004.obj
# Processing frame 5...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_004.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0005.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_004.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0005.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.302477
# Final scale applied: 1.302477
# Translation applied: [-0.00789773 -0.00488424  0.02316771]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0005.obj
# Processing frame 6...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_005.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0006.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_005.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0006.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.293700
# Final scale applied: 1.293700
# Translation applied: [-0.00786424 -0.00517225  0.02512419]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0006.obj
# Processing frame 7...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_006.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0007.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_006.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0007.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.298724
# Final scale applied: 1.298724
# Translation applied: [-0.00787424 -0.00516224  0.0251192 ]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0007.obj
# Processing frame 8...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_007.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0008.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_007.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0008.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.300577
# Final scale applied: 1.300577
# Translation applied: [-0.00788073 -0.00514227  0.0251137 ]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0008.obj
# Processing frame 9...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_008.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0009.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_008.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0009.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.305934
# Final scale applied: 1.305934
# Translation applied: [-0.00792573 -0.00516224  0.02517672]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0009.obj
# Processing frame 10...
# Source: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_009.obj
# Output: /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0010.obj
# Running: python align_mesh.py --source /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/original/dancer_009.obj --target /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_no_texture/dancer_0001.obj --output /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0010.obj --auto_scale --anchor center --bbox_type aabb
#
# Source mesh
#   Vertices : 19712
#   Triangles: 39412
#   Has UVs  : False
#   Has tex  : False
#   Has vtx colors: False
#
# Target mesh
#   Vertices : 118130
#   Triangles: 39380
#   Has UVs  : True
#   Has tex  : False
#   Has vtx colors: False
#
# Auto scale ratio: 1.315260
# Final scale applied: 1.315260
# Translation applied: [-0.00785224 -0.00373673  0.02518271]
# [Open3D WARNING] Write OBJ can not include triangle normals.
#
# Saved transformed textured mesh to:
#   /home/frozzzen/Documents/Github/layered-mesh-gaussian/data/dancer/meshes_TSMC/dancer_0010.obj
# All frames processed.
